# %%
import sys
sys.path.append('../')

# %%
from titanic_pro.utils import load_data

train_df, test_df = load_data()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     131 non-null    int64
#  1   survived   131 non-null    int64
#  2   name       131 non-null    object
#  3   sex        131 non-null    object
#  4   age        104 non-null    object
#  5   sibsp      131 non-null    int64
#  6   parch      131 non-null    int64
#  7   ticket     131 non-null    object
#  8   fare       131 non-null    object
#  9   cabin      28 non-null     object
#  10  embarked   131 non-null    object
#  11  boat       50 non-null     object
#  12  body       5 non-null      float64
#  13  home.dest  73 non-null     object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 14.5+ KB

# %%
train_df.head()
# Out:
#    pclass  survived                                   name     sex  age  \
# 0       1         1         Fortune, Miss. Alice Elizabeth  female   24
# 1       3         0                      Assaf, Mr. Gerios    male   21
# 2       3         0                     Bourke, Miss. Mary  female  NaN
# 3       1         0  Chisholm, Mr. Roderick Robert Crispin    male  NaN
# 4       2         0                     Herman, Mr. Samuel    male   49
#
#    sibsp  parch  ticket      fare        cabin embarked boat  body  \
# 0      3      2   19950  263,0000  C23 C25 C27        S   10   NaN
# 1      0      0    2692    7,2250          NaN        C  NaN   NaN
# 2      0      2  364848    7,7500          NaN        Q  NaN   NaN
# 3      0      0  112051    0,0000          NaN        S  NaN   NaN
# 4      1      2  220845   65,0000          NaN        S  NaN   NaN
#
#                       home.dest
# 0                  Winnipeg, MB
# 1                    Ottawa, ON
# ...
